# %%
#dependencies
import csv 
import pandas as pd
import matplotlib.pyplot as plt

# %%
#create pandas dataframe for historical crime data (2017) from csv file
crime_data_df = pd.read_csv("Resources/2017-PART_I_AND_II_CRIMES.csv")
crime_data_df.head()
# Out:
#    LURN_SAK    INCIDENT_DATE INCIDENT_REPORTED_DATE  \
# 0  18288959   8/3/2017 23:53               8/3/2017
# 1  18079991    3/7/2017 8:23               3/7/2017
# 2  18215223   5/24/2017 9:20              5/24/2017
# 3  18077911   3/4/2017 22:18               3/4/2017
# 4  18382253  10/31/2017 5:00             10/31/2017
#
#                       CATEGORY  STAT  \
# 0       VEHICLE / BOATING LAWS   255
# 1   MISCELLANEOUS NON-CRIMINAL   720
# 2   MISCELLANEOUS NON-CRIMINAL   501
# 3   MISCELLANEOUS NON-CRIMINAL   687
# 4  ACCIDENTS TRAFFIC/VEH./BOAT   471
#
#                                            STAT_DESC  \
# 0              VEHICLE AND BOATING LAWS: Misdemeanor
# 1  VEHICLE/BOATING LAWS, CITATIONS: Hazardous Cit...
# 2                 MISCELLANEOUS: Vehicle Repossessed
# 3  NON-CRIMINAL, CUSTODY INCIDENTS - Inmate Sick/...
# 4  ACCIDENTS, TRAFFIC-VEHICLE OR BOAT: Accident, ...
#
#                                          ADDRESS                  STREET  \
# ...

# %%
crime_data_df
# Out:
#         LURN_SAK     INCIDENT_DATE INCIDENT_REPORTED_DATE  \
# 0       18288959    8/3/2017 23:53               8/3/2017
# 1       18079991     3/7/2017 8:23               3/7/2017
# 2       18215223    5/24/2017 9:20              5/24/2017
# 3       18077911    3/4/2017 22:18               3/4/2017
# 4       18382253   10/31/2017 5:00             10/31/2017
# 5       18078130     3/5/2017 4:30               3/5/2017
# 6       18181132    4/11/2017 0:00              4/24/2017
# 7       18015552    1/5/2017 13:50               1/5/2017
# 8       18177210   4/20/2017 10:46              4/20/2017
# 9       18173307   4/16/2017 21:00              4/16/2017
# 10      18422806  12/10/2017 15:55             12/10/2017
# 11      18163154     4/6/2017 5:15               4/6/2017
# 12      18204252    5/17/2017 9:51              5/17/2017
# 13      18030360    5/5/2016 16:15              1/18/2017
# 14      18191985    4/29/2017 7:00               5/4/2017
# ...

# %%
gp_crime_data_df=crime_data_df.groupby(['UNIT_NAME','CATEGORY'])

# %%
gp_crime_data_df.count()
# Out:
#                                              LURN_SAK  INCIDENT_DATE  \
# UNIT_NAME      CATEGORY
# ADMIN          ACCIDENTS TRAFFIC/VEH./BOAT         20             20
#                AGGRAVATED ASSAULT                  21             21
#                BURGLARY                             1              1
#                DISORDERLY CONDUCT                   3              3
#                FEDERAL OFFENSES W/O MONEY           1              1
#                FEDERAL OFFENSES WITH MONEY          1              1
#                FELONIES MISCELLANEOUS              10             10
#                FRAUD AND NSF CHECKS                 1              1
#                MENTALLY ILL                         5              5
#                MISCELLANEOUS NON-CRIMINAL         616            616
#                MISDEMEANORS MISCELLANEOUS           2              2
#                NARCOTICS                            3              3
# ...
