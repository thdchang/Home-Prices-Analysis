# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import numpy as np
import requests
import json
import csv
import gmaps
# Google API Key
from config import gkey
from pprint import pprint
gkey
# Out:
# 'AIzaSyBL8ahyFy8MhoDCjB1wwwb0m3i2cVBBulE'

# %%
#Read LA county lat and long csv file
house_p_df = pd.read_csv("res_la_house_price.csv")
#house_p_df.head()
#house_p_df.rename(columns={"CountyName":"county"})
house_p_df.head()
#new_county=[]
#for row in house_p_df:
  #  print(row["CountyName"])
    #new_county.append(row)
# Out:
#    RegionID   RegionName State                           Metro   CountyName  \
# 0     12447  Los Angeles    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 1     46298   Long Beach    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 2     45457     Glendale    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 3      5534    Lancaster    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 4     40227     Palmdale    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
#
#    2018-05
# 0   714700
# 1   633200
# 2   927000
# 3   279200
# 4   309700

# %%
house_p_df.count()
# Out:
# RegionID      113
# RegionName    113
# State         113
# Metro         113
# CountyName    113
# 2018-05       113
# dtype: int64

# %%
house_p_df=house_p_df.loc[house_p_df['RegionName'].isin(['Pasadena','Cerritos','Torrance'])]
house_p_df
# Out:
#     RegionID RegionName State                           Metro   CountyName  \
# 7      47019   Pasadena    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 8      54722   Torrance    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 45     10774   Cerritos    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
#
#     2018-05
# 7    921500
# 8    866700
# 45   742700

# %%
#Read LA county lat and long csv file
la_long_df = pd.read_csv("zip_codes_states_LA_COUNTY.csv")
la_long_df.head()
# Out:
#    zip_code   latitude   longitude   RegionName State   CountyName
# 0     90001  33.973951 -118.248405  Los Angeles    CA  Los Angeles
# 1     90002  33.950514 -118.245855  Los Angeles    CA  Los Angeles
# 2     90003  33.949164 -118.273156  Los Angeles    CA  Los Angeles
# 3     90004  33.786594 -118.298662  Los Angeles    CA  Los Angeles
# 4     90005  33.786594 -118.298662  Los Angeles    CA  Los Angeles

# %%
la_long_df['location']=la_long_df[['latitude','longitude','RegionName']].apply(lambda x:'{},{},{}'.format(x[0],x[1],x[2]),axis=1)
la_long_df.count()
# Out:
# zip_code      531
# latitude      528
# longitude     528
# RegionName    531
# State         531
# CountyName    531
# location      531
# dtype: int64

# %%
la_long_df=la_long_df.dropna()
la_long_df.count()
# Out:
# zip_code      528
# latitude      528
# longitude     528
# RegionName    528
# State         528
# CountyName    528
# location      528
# dtype: int64

# %%
pct_combined=la_long_df.loc[la_long_df['RegionName'].isin(['Pasadena','Cerritos','Torrance'])]
number_city=pct_combined.count()
print(f"The total number of zipcode in torrance,Cerritos and Pasadena {number_city}")
# Out:
# The total number of zipcode in torrance,Cerritos and Pasadena zip_code      42
# latitude      42
# longitude     42
# RegionName    42
# State         42
# CountyName    42
# location      42
# dtype: int64

# %%
pct_combined.head()
# Out:
#      zip_code   latitude   longitude RegionName State   CountyName  \
# 176     90501  33.835665 -118.303805   Torrance    CA  Los Angeles
# 177     90502  33.833816 -118.293405   Torrance    CA  Los Angeles
# 178     90503  33.786594 -118.298662   Torrance    CA  Los Angeles
# 179     90504  33.786594 -118.298662   Torrance    CA  Los Angeles
# 180     90505  33.786594 -118.298662   Torrance    CA  Los Angeles
#
#                                             location
# 176  33.835665000000006,-118.30380500000001,Torrance
# 177                   33.833816,-118.293405,Torrance
# 178           33.786594,-118.29866200000001,Torrance
# 179           33.786594,-118.29866200000001,Torrance
# 180           33.786594,-118.29866200000001,Torrance

# %%
pct_combined.count()
# Out:
# zip_code      42
# latitude      42
# longitude     42
# RegionName    42
# State         42
# CountyName    42
# location      42
# dtype: int64

# %%
#df.loc[df['channel'].isin(['sale','fullprice'])]

# %%
#df.drop_duplicates(['first_name'], keep='last')

# %%
drop_same_locatio=pct_combined.drop_duplicates(['location'],keep='first')
drop_same_locatio.count()
# Out:
# zip_code      5
# latitude      5
# longitude     5
# RegionName    5
# State         5
# CountyName    5
# location      5
# dtype: int64

# %%
# df.to_csv('example.csv')
pct_combined.to_csv('new_city_pct_list.csv')

# %%
# find the closest restaurant of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
   # "location": "33.786594,-118.298662",  # zip_code 90001 coords,
    "rankby": "distance",
    "type": "restaurant",
    "keyword":"organic",
    "key": gkey,
}

res_name=[]
#RegionName=[]
res_address=[]
res_level=[]
res_rating=[]
res_location=[]
#lat=[]
#lon=[]

compond_list={"Resturant name":res_name,
           #   "lat" :lat,
           #   "lon" :lon,
              "Location":res_location,
              "Address" :res_address,
              "Price level":res_level,
              "Rating":res_rating }
# use iterrows to iterate through pandas dataframe
for index, row in drop_same_locatio.iterrows():

    # get restaurant type from df
    #restr_type = row['ethnicity']
    lat=row['latitude']
    lon=row['longitude']
   # RegionName=row['RegionName']
    # add keyword to params dict
    params['location'] =f'{lat},{lon}'

    # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {lat},{lon}")
    response = requests.get(base_url, params=params).json()
  #  results = response.get('results')
    #print(results)
    
    # extract first result and use pd.set_value to insert into dataframe
    results = response.get('results')
    pprint(results)
    for x in range(20):
        if (results):
       
            restr = response['results'][x]
          ##  print(f"Closest {lat},{lon} restaurant is {restr.get('name', 'Unknown')}.")
            pct_combined.loc[index, 'name'] = restr.get('name', '')
            res_name.append(restr.get('name', ''))
           # lat.append(str(lat))
           # lon.append(str(lon))
            pct_combined.loc[index, 'address'] = restr.get('vicinity', '')
            res_address.append(restr.get('vicinity', ''))
            pct_combined.loc[index, 'price_level'] = restr.get('price_level', '')
            res_level.append(restr.get('price_level', ''))
            res_location.append(restr.get('geometry','location'))
            pct_combined.loc[index, 'rating'] = restr.get('rating', '')
            res_rating.append(restr.get('rating', ''))
        else:
            print("No results for " + lat+lon)
            print("------------")
#print(compond_list)
# Out:
# Retrieving Results for Index 176: 33.835665000000006,-118.30380500000001
# [{'geometry': {'location': {'lat': 33.8366772, 'lng': -118.318935},
#                'viewport': {'northeast': {'lat': 33.83787732989272,
#                                           'lng': -118.3175959701073},
#                             'southwest': {'lat': 33.83517767010728,
#                                           'lng': -118.3202956298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '5d7544a0a56d95a23bf61e383dbe41b5ad2db43c',
#   'name': 'The Good Cookies & Beyond - A Gluten Free Bakery',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2048,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/
927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'bb2d61cc6f1163163009062bb95ce6afa4b8fb4d',
#   'name': 'Mr. Wisdom Organic Health Food Hare Krishna',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 648,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/113616406047891300708/photos">Mcclendon '
#                                     'Tessa</a>'],
#               'photo_reference': 'CmRaAAAAwtx0kHvUcWuXi-9o_jKEqDNHg5QQakKCmEUTg1EZRssUI3WaJqmYnW_vwt9rL4szj85Xk0BhYOgHIaNIhUYAkT7mO7ZHnXbVlEJJ8pImwDR1_xMxR5bE6suRWPTRGkavEhCgdy_VLqlVaGTsTmfcWRHBGhRAbjZKOhXhZmjcjHKiyJNzjhRnQQ',
#               'width': 488}],
#   'place_id': 'ChIJvUwNU5e3woARBZfnQqcxJPc',
#   'plus_code': {'compound_code': 'XMQ8+G9 Los Angeles, California',
#                 'global_code': '8553XMQ8+G9'},
#   'rating': 4.7,
#   'reference': 'CmRbAAAARqcSlERY9KGgJ6EFoy0cVRxn7XVc38C_LXFdKgg-LaJ1t0749EfkN5771yMLf_WOhLH20i9rKBm2ZjSdiPSkesMiHmPPhZtsQyhvZMooNOOTOUxWZLJ2vo22VXydXw6eEhDv_H7zifSdiZFN8-6voQSQGhTT72retJee7d29pxVcZKahy1z6dQ',
#   'scope': 'GOOGLE',
#   'types': ['store',
#             'health',
#             'restaurant',
#             'food',
#             'point_of_interest',
#             'establishment'],
#   'vicinity': '3526 W Slauson Ave, Los Angeles'},
#  {'geometry': {'location': {'lat': 34.00424, 'lng': -118.409539},
#                'viewport': {'northeast': {'lat': 34.00567162989272,
#                                           'lng': -118.4081154201073},
#                             'southwest': {'lat': 34.00297197010728,
#                                           'lng': -118.4108150798927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '73877c1532b96605caf85c092cf435290996de90',
#   'name': 'Fresh Pita Organic Express',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3456,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/105613137209343207180/photos">Fresh '
#                                     'Pita Organic Mediterranean Fusion</a>'],
#               'photo_reference': 'CmRaAAAAV35x4Vpm-Ssm2ACwtv6_AyEHMym4MRZVsUyxmQxcJT8gvp7zrl3HqIxth1FAXdPA_K3Ps3BdqG-P0RyhAf3JA6cFu3WbcHzV2XPg9dGJCdt1SO-cs9hDoIiHdhm8h55KEhBqeumD4zS4MzrSpyzBi6lfGhQnAgd5MivBMumgFKxQNoOCpQsLEw',
#               'width': 5184}],
#   'place_id': 'ChIJ50L-bha6woARoT_HshdTLLQ',
#   'plus_code': {'compound_code': '2H3R+M5 Culver City, California',
#                 'global_code': '85632H3R+M5'},
#   'price_level': 1,
#   'rating': 4.2,
#   'reference': 'CmRbAAAAau7ffw8G7xiYqqjmN09d5Flts2mKO15uzQfMAGdpK1FLHEBWZqyCWSp_wJ8gKcC8r1_EBssn4ViP2TCkSoTfz77tXCdQnWDWMjt5vnTqwN1lRyRtkTSNrODCoGX5IM0EEhDfG2S7PdX8ZNg3JpxSrjZtGhRxVnOLRJqDMqVkP-U20zJbjBTCiw',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '4315 Sepulveda Blvd, Culver City'},
#  {'geometry': {'location': {'lat': 34.0065368, 'lng': -118.41216},
#                'viewport': {'northeast': {'lat': 34.00779432989272,
#                                           'lng': -118.4109668701073},
#                             'southwest': {'lat': 34.00509467010728,
#                                           'lng': -118.4136665298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '2f02bec4e967245c8d40db11936bfec3d4704644',
#   'name': 'Sage Plant Based Bistro West',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1000,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/

#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2448,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/107795357580888987741/photos">SuperFood '
#                                     'Cafe</a>'],
#               'photo_reference': 'CmRaAAAAH4wAudg7vPZoKuE1GPV8Xw06VyjtK1sIrQUX32W-I-ykGiz4HBnCgmTUQp-7Q3pioXZLFlQ5Ot99yHTi4zSBjE9vsw1csKJdNsZ7P2viXKNmfuH1cJ2SHK0PpEyXWjkPEhDQpWGiydbrWMEDEyCRJW0_GhTR6CkeMxcolNL3DbVCw6i6C3gn_Q',
#               'width': 3264}],
#   'place_id': 'ChIJ34yhy8ikwoARb27Kvqnu1_4',
#   'plus_code': {'compound_code': '2GC3+4C Santa Monica, California',
#                 'global_code': '85632GC3+4C'},
#   'rating': 4.6,
#   'reference': 'CmRbAAAAGPBw1q1YvEAKqgG3TzWAMB2FgeItQOre0JShwUOTgI2EYlfP37--_rvEBghgujhVqGTxyAs30OUeZDNUqlZlbRmVTZEiMMj9CNR35ilU1Ig5DgOLwuL91bCbRAS6w83KEhAfaittwmpSfqm1RR-fK_kaGhRzmT7SqdFOln2S8gI4Ww2iIyMO9Q',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '530 Wilshire Blvd, Santa Monica'},
#  {'geometry': {'location': {'lat': 34.0771192, 'lng': -118.2587199},
#                'viewport': {'northeast': {'lat': 34.07856197989273,
#                                           'lng': -118.2573112201073},
#                             'southwest': {'lat': 34.07586232010728,
#                                           'lng': -118.2600108798928}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': 'd8bc8d867ccf72cbc552e100238a0820628963ee',
#   'name': 'Sage Plant Based Bistro and Brewery Echo Park',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/105756638182226336287/photos">Anurag '
#                                     'Singhai</a>'],
#               'photo_reference': 'CmRaAAAAPqUdBC73L9_ahrmlTaoGr2ihAvAWB9JTxr8Nn81Vacj22LGLwVwHDzf-0Mhmb1QN_ljWGPKwrFoFNabjTgNQJsB6F0BDSrWOxXpLnIF7Xgs8tqGkSm8je8dINa4wIpaOEhBs5OzZdSfAlOeeSIaiqaBOGhS3y8O6Bs_ePUdBP4Mz6oDqVb6q0w',
#               'width': 4032}],
#   'place_id': 'ChIJ6T9ggBvHwoARc3aegK3PBe0',
#   'plus_code': {'compound_code': '3PGR+RG Los Angeles, California',
#                 'global_code': '85633PGR+RG'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'CmRbAAAA5KP37uTsaDH9gYGc4Wtl-F6gmN9tlthJ1Y6ma36bsjylToKPz2KK_vQ9SqiAW14phBA-NWRIABAXZpd7t5C5jiLMp4N1GnJY076u0bKJG6-iu2rFS6E-O0p7gRpfeXhSEhDCz_vuDRWQXfekceUbcVUfGhTCoD-kc3t2jFYEa-_pe3U_mGCdTg',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '1700 Sunset Blvd, Los Angeles'},
#  {'geometry': {'location': {'lat': 34.0325744, 'lng': -118.4944729},
#                'viewport': {'northeast': {'lat': 34.03397827989271,
#                                           'lng': -118.4931872701073},
#                             'southwest': {'lat': 34.03127862010727,
#                                           'lng': -118.4958869298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/cafe-71.png',
#   'id': '0f6a80d7df0edd0af2ff3d8f1b824e53923b9d6f',
#   'name': 'Beaming Organic Superfood Café',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/111912693773858789552/photos">Lo '
#                                     'Shia</a>'],
#               'photo_reference': 'CmRaAAAATeTuwLsKQlpjL4l0owVkL2Fvf_nC_VT4iYdvPduNYidBTIcMdi9mnpAGtRJivzdsqCyE2gyWgSXZT4oGIBPLcea3SJG6fcQG3iDCPXQgq5wzvrAa2743UoPvfPZ0MVelEhBbMLGUtiJDpLz7iihJ3eVhGhSMJ9_0Tqgo-hcSjziX4YbdSCG1KQ',
#               'width': 3024}],
#   'place_id': 'ChIJaWQ_ELGkwoARaRHnRFYodVA',
#   'plus_code': {'compound_code': '2GM4+26 Santa Monica, California',
#                 'global_code': '85632GM4+26'},
#   'rating': 4.5,
#   'reference': 'CmRbAA

#   'scope': 'GOOGLE',
#   'types': ['meal_takeaway',
#             'restaurant',
#             'food',
#             'point_of_interest',
#             'establishment'],
#   'vicinity': '2943 Sunset Blvd, Los Angeles'},
#  {'geometry': {'location': {'lat': 34.090791, 'lng': -118.390096},
#                'viewport': {'northeast': {'lat': 34.09205052989271,
#                                           'lng': -118.3887456701073},
#                             'southwest': {'lat': 34.08935087010727,
#                                           'lng': -118.3914453298927}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '5671326577009f99ee10d5efbfcdbfae226b93d2',
#   'name': 'Gravitè',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3036,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/116156430611797530851/photos">Ding '
#                                     'Liu</a>'],
#               'photo_reference': 'CmRZAAAA_gpdoui4IHZX0r9ab4C0NrzIYMbTdBHfsrT59vB_AeByndz-PauhSSBtOCp-T95F28XtvbvdSo8aJtPLXAQMw_wo9rioWL5FvvSbKzCJ1o1S3SZJ1-HhSzHzahM0fFRzEhBGSbPngXeT-jqcpBC87WOPGhQCwhY4aWEDkgXO59OMRzRO9Erteg',
#               'width': 4048}],
#   'place_id': 'ChIJ1ya8UqC-woAR5MCk-2AWfbA',
#   'plus_code': {'compound_code': '3JR5+8X West Hollywood, Central LA, CA',
#                 'global_code': '85633JR5+8X'},
#   'price_level': 1,
#   'rating': 4.5,
#   'reference': 'CmRbAAAACEhmk042jVlapDDvxvlV5RYZlMwz-cSAS_hnXTJaMYhVNR7ABVWogyjeYTCiKf9wH3Y3lC4UEca4j3vPR__TVpdsgKyCSt4Rmbm21Y571jO-wkh-h-f0JWNQ_IWWi1vmEhBaly1QStrawxyyXBIAzikbGhRgIBSnWD8qSG-l6eZLUYmQripCPg',
#   'scope': 'GOOGLE',
#   'types': ['cafe', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '9107 Sunset Blvd, West Hollywood'},
#  {'geometry': {'location': {'lat': 34.100517, 'lng': -118.32927},
#                'viewport': {'northeast': {'lat': 34.10186592989272,
#                                           'lng': -118.3280567701073},
#                             'southwest': {'lat': 34.09916627010728,
#                                           'lng': -118.3307564298928}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png',
#   'id': '6f077e7974b8d7994cdcd190845cb86862e2030c',
#   'name': 'The Running Goose- Restaurant and Organic Herb Garden',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3036,
#               'html_attributions': ['<a '
#                                     'href="https://maps.google.com/maps/contrib/116633762380321965919/photos">Menoman '
#                                     'Martinez</a>'],
#               'photo_reference': 'CmRaAAAA3h_cNCHsMH-fBfVZY4QfRL9fHyjQDkvcMlbj6Yq8_XCxZvO_oyu7nOkaP8ieXpl4VeNqti4b3-OAlbOpbYSCZHe9sgVL2yBtKN_HIWzE_VlgZWsGIqtZCh1xfbAo54OUEhBz5GkyvreWEUBb4uJ0m3K6GhQVyY01suSONOgiFRKb8f2JFvlyxg',
#               'width': 4048}],
#   'place_id': 'ChIJ18Rb0ju_woAR62u9t9xtwzc',
#   'plus_code': {'compound_code': '4M2C+67 Los Angeles, California',
#                 'global_code': '85634M2C+67'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'CmRbAAAAhnW1Gqnopxa13iye1rzpzggar-wRgVW4CvkTScWQ1vVxV9tQfMNkz9_tVxe4RIpqjBhNNxre8cRyGfEO616nisSxatfKLsPRpvddRSpUfIzDrSrRWtPuNN9BR7wB-HnIEhC5wqUyz-LnWvNJx05E3Q5PGhTopyPDrZqRvztlX-yedG-7NixTyA',
#   'scope': 'GOOGLE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'vicinity': '1620 N Cahuenga Blvd, Los Angeles'}]

# %%
res_area_list=pd.DataFrame(compond_list)
res_area_list.head()
# Out:
#                                    Address  \
# 0             2081 Torrance Blvd, Torrance
# 1      23211 Hawthorne Blvd #100, Torrance
# 2  1700 S Catalina Ave #103, Redondo Beach
# 3       1735 S Catalina Ave, Redondo Beach
# 4              509 Pier Ave, Hermosa Beach
#
#                                             Location Price level  Rating  \
# 0  {'location': {'lat': 33.8366772, 'lng': -118.3...           2     4.6
# 1  {'location': {'lat': 33.815576, 'lng': -118.35...                 5.0
# 2  {'location': {'lat': 33.8189633, 'lng': -118.3...           2     4.7
# 3  {'location': {'lat': 33.817329, 'lng': -118.38...           2     4.6
# 4  {'location': {'lat': 33.8645386, 'lng': -118.3...                 4.5
#
#                                      Resturant name
# 0  The Good Cookies & Beyond - A Gluten Free Bakery
# 1                                         OrganiKos
# 2                                  The Green Temple
# 3                              Turquoise Restaurant
# 4                                   The Source Cafe

# %%
latitude_list = []
longitude_list = []

# %%
for index, row in res_area_list.iterrows():
    loc_lat = res_area_list['Location'][index]['location']['lat']
    loc_lng = res_area_list['Location'][index]['location']['lng']
    latitude_list.append(loc_lat)
    longitude_list.append(loc_lng)

res_area_list['Latitude'] = latitude_list
res_area_list['Longitude'] = longitude_list

# %%
res_area_list.head()
# Out:
#                                    Address  \
# 0             2081 Torrance Blvd, Torrance
# 1      23211 Hawthorne Blvd #100, Torrance
# 2  1700 S Catalina Ave #103, Redondo Beach
# 3       1735 S Catalina Ave, Redondo Beach
# 4              509 Pier Ave, Hermosa Beach
#
#                                             Location Price level  Rating  \
# 0  {'location': {'lat': 33.8366772, 'lng': -118.3...           2     4.6
# 1  {'location': {'lat': 33.815576, 'lng': -118.35...                 5.0
# 2  {'location': {'lat': 33.8189633, 'lng': -118.3...           2     4.7
# 3  {'location': {'lat': 33.817329, 'lng': -118.38...           2     4.6
# 4  {'location': {'lat': 33.8645386, 'lng': -118.3...                 4.5
#
#                                      Resturant name   Latitude   Longitude
# 0  The Good Cookies & Beyond - A Gluten Free Bakery  33.836677 -118.318935
# 1                                         OrganiKos  33.815576 -118.351367
# 2                                  The Green Temple  33.818963 -118.387877
# 3                              Turquoise Restaurant  33.817329 -118.387987
# 4                                   The Source Cafe  33.864539 -118.396692

# %%
del res_area_list['Location']

# %%
res_area_list.head()
# Out:
#                                    Address Price level  Rating  \
# 0             2081 Torrance Blvd, Torrance           2     4.6
# 1      23211 Hawthorne Blvd #100, Torrance                 5.0
# 2  1700 S Catalina Ave #103, Redondo Beach           2     4.7
# 3       1735 S Catalina Ave, Redondo Beach           2     4.6
# 4              509 Pier Ave, Hermosa Beach                 4.5
#
#                                      Resturant name   Latitude   Longitude
# 0  The Good Cookies & Beyond - A Gluten Free Bakery  33.836677 -118.318935
# 1                                         OrganiKos  33.815576 -118.351367
# 2                                  The Green Temple  33.818963 -118.387877
# 3                              Turquoise Restaurant  33.817329 -118.387987
# 4                                   The Source Cafe  33.864539 -118.396692

# %%
res_area_list['City'] =res_area_list['Address'].str.rsplit(',').str[-1] 
res_area_list.head()
# Out:
#                                    Address Price level  Rating  \
# 0             2081 Torrance Blvd, Torrance           2     4.6
# 1      23211 Hawthorne Blvd #100, Torrance                 5.0
# 2  1700 S Catalina Ave #103, Redondo Beach           2     4.7
# 3       1735 S Catalina Ave, Redondo Beach           2     4.6
# 4              509 Pier Ave, Hermosa Beach                 4.5
#
#                                      Resturant name   Latitude   Longitude  \
# 0  The Good Cookies & Beyond - A Gluten Free Bakery  33.836677 -118.318935
# 1                                         OrganiKos  33.815576 -118.351367
# 2                                  The Green Temple  33.818963 -118.387877
# 3                              Turquoise Restaurant  33.817329 -118.387987
# 4                                   The Source Cafe  33.864539 -118.396692
#
#              City
# 0        Torrance
# 1        Torrance
# 2   Redondo Beach
# 3   Redondo Beach
# 4   Hermosa Beach

# %%
res_area_list=res_area_list.rename(index=str, columns={"City": "RegionName"})

# %%
res_area_list.head()
# Out:
#                                    Address Price level  Rating  \
# 0             2081 Torrance Blvd, Torrance           2     4.6
# 1      23211 Hawthorne Blvd #100, Torrance                 5.0
# 2  1700 S Catalina Ave #103, Redondo Beach           2     4.7
# 3       1735 S Catalina Ave, Redondo Beach           2     4.6
# 4              509 Pier Ave, Hermosa Beach                 4.5
#
#                                      Resturant name   Latitude   Longitude  \
# 0  The Good Cookies & Beyond - A Gluten Free Bakery  33.836677 -118.318935
# 1                                         OrganiKos  33.815576 -118.351367
# 2                                  The Green Temple  33.818963 -118.387877
# 3                              Turquoise Restaurant  33.817329 -118.387987
# 4                                   The Source Cafe  33.864539 -118.396692
#
#        RegionName
# 0        Torrance
# 1        Torrance
# 2   Redondo Beach
# 3   Redondo Beach
# 4   Hermosa Beach

# %%
#Usually you want this result as a DataFrame (instead of a Series) so you can do:

#df.groupby(['col1', 'col2']).size().reset_index(name='counts')

res_gp=res_area_list.groupby(['RegionName']).size().reset_index(name='counts')
res_gp.head()
# Out:
#      RegionName  counts
# 0       Anaheim       1
# 1       Arcadia       1
# 2          Brea       1
# 3      Cerritos       1
# 4   Culver City       9

# %%
x_axis = np.arange(len(RegionName))

# %%
# Create a bar chart based upon the above data
plt.bar(x_axis, total_count, color="r", align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 21 artists>

# %%
# Create the ticks for our bar chart's x axis
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, RegionName)
# Out:
# ([<matplotlib.axis.XTick at 0x106ef3550>,
#   <matplotlib.axis.XTick at 0x10792e630>,
#   <matplotlib.axis.XTick at 0x10cd5e8d0>,
#   <matplotlib.axis.XTick at 0x10cdc0198>,
#   <matplotlib.axis.XTick at 0x10cdc07f0>,
#   <matplotlib.axis.XTick at 0x10cdc0e48>,
#   <matplotlib.axis.XTick at 0x10cdc84e0>,
#   <matplotlib.axis.XTick at 0x106ed9278>,
#   <matplotlib.axis.XTick at 0x1174a3400>,
#   <matplotlib.axis.XTick at 0x1174a3978>,
#   <matplotlib.axis.XTick at 0x1174a3fd0>,
#   <matplotlib.axis.XTick at 0x1174b3668>,
#   <matplotlib.axis.XTick at 0x1174b3cf8>,
#   <matplotlib.axis.XTick at 0x1182ca470>,
#   <matplotlib.axis.XTick at 0x10cda0780>,
#   <matplotlib.axis.XTick at 0x11749c748>,
#   <matplotlib.axis.XTick at 0x1182caa90>,
#   <matplotlib.axis.XTick at 0x1182cf160>,
#   <matplotlib.axis.XTick at 0x1182cf7f0>,
#   <matplotlib.axis.XTick at 0x1182cfe80>,
#   <matplotlib.axis.XTick at 0x1182d4550>],
#  <a list of 21 Text xticklabel objects>)

# %%
#if you want to make a list
list_count_city=res_area_list.groupby(['RegionName']).size()
list_count_city.head()
# Out:
# RegionName
#  Anaheim        1
#  Arcadia        1
#  Brea           1
#  Cerritos       1
#  Culver City    9
# dtype: int64

# %%
#Read LA county lat and long csv file
house_p_df = pd.read_csv("res_la_house_price.csv")
#house_p_df.head()
#house_p_df.rename(columns={"CountyName":"county"})
house_p_df.head()
#new_county=[]
#for row in house_p_df:
  #  print(row["CountyName"])
    #new_county.append(row)
# Out:
#    RegionID   RegionName State                           Metro   CountyName  \
# 0     12447  Los Angeles    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 1     46298   Long Beach    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 2     45457     Glendale    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 3      5534    Lancaster    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
# 4     40227     Palmdale    CA  Los Angeles-Long Beach-Anaheim  Los Angeles
#
#    2018-05
# 0   714700
# 1   633200
# 2   927000
# 3   279200
# 4   309700

# %%
del house_p_df['RegionID']
del house_p_df['State']
del house_p_df['Metro']

# %%
res_area_list.head()
# Out:
#                                    Address Price level  Rating  \
# 0             2081 Torrance Blvd, Torrance           2     4.6
# 1      23211 Hawthorne Blvd #100, Torrance                 5.0
# 2  1700 S Catalina Ave #103, Redondo Beach           2     4.7
# 3       1735 S Catalina Ave, Redondo Beach           2     4.6
# 4              509 Pier Ave, Hermosa Beach                 4.5
#
#                                      Resturant name   Latitude   Longitude  \
# 0  The Good Cookies & Beyond - A Gluten Free Bakery  33.836677 -118.318935
# 1                                         OrganiKos  33.815576 -118.351367
# 2                                  The Green Temple  33.818963 -118.387877
# 3                              Turquoise Restaurant  33.817329 -118.387987
# 4                                   The Source Cafe  33.864539 -118.396692
#
#        RegionName
# 0        Torrance
# 1        Torrance
# 2   Redondo Beach
# 3   Redondo Beach
# 4   Hermosa Beach

# %%
del res_area_list['Address']
del res_area_list['Resturant name']

# %%
res_area_list.head()
# Out:
#   Price level  Rating   Latitude   Longitude      RegionName
# 0           2     4.6  33.836677 -118.318935        Torrance
# 1                 5.0  33.815576 -118.351367        Torrance
# 2           2     4.7  33.818963 -118.387877   Redondo Beach
# 3           2     4.6  33.817329 -118.387987   Redondo Beach
# 4                 4.5  33.864539 -118.396692   Hermosa Beach

# %%
res_area_list.to_csv("res_area_list.csv")

# %%
house_p_df.head()
# Out:
#     RegionName   CountyName  2018-05
# 0  Los Angeles  Los Angeles   714700
# 1   Long Beach  Los Angeles   633200
# 2     Glendale  Los Angeles   927000
# 3    Lancaster  Los Angeles   279200
# 4     Palmdale  Los Angeles   309700

# %%
#merge organic rest with city single house data
data1=pd.read_csv('House_price_range.csv')
data2=pd.read_csv('res_area_list.csv')
data2['RegionName']=data2['RegionName'].str[1:]
merge=pd.merge(data1,data2,how='left',on='RegionName')

# %%
merge.head()
# Out:
#     RegionName State   CountyName  2018-05  Unnamed: 0_x  Price level_x  \
# 0  Los Angeles    CA  Los Angeles   714700           7.0            NaN
# 1  Los Angeles    CA  Los Angeles   714700           7.0            NaN
# 2  Los Angeles    CA  Los Angeles   714700           7.0            NaN
# 3  Los Angeles    CA  Los Angeles   714700           7.0            NaN
# 4  Los Angeles    CA  Los Angeles   714700           7.0            NaN
#
#    Rating_x  Latitude_x  Longitude_x House Price Ranking  Unnamed: 0_y  \
# 1810               Littlerock     NaN    CA  Los Angeles   269900
# 1811          Avocado Heights     NaN    CA  Los Angeles   560300
# 1812              Signal Hill     NaN    CA  Los Angeles   687500
# 1813              West Athens     NaN    CA  Los Angeles   487500
# 1814     Palos Verdes Estates     NaN    CA  Los Angeles  2143400
# 1815             Alondra Park     NaN    CA  Los Angeles   617400
# 1816                  Topanga     NaN    CA  Los Angeles  1268900
# 1817           Ladera Heights     NaN    CA  Los Angeles  1273400
# 1818           East La Mirada     NaN    CA  Los Angeles   587500
# 1819         La Habra Heights     NaN    CA  Los Angeles   979700
# 1820                    Acton     NaN    CA  Los Angeles   596900
# 1821                   Avalon     NaN    CA  Los Angeles   759100
# 1822              Pearblossom     NaN    CA  Los Angeles   235600
# 1823    Rolling Hills Estates     NaN    CA  Los Angeles  1565800
# 1824            Rolling Hills     NaN    CA  Los Angeles  3346100
# 1825             Hidden Hills     NaN    CA  Los Angeles  3323600
# 1826   Palos Verdes Peninsula     NaN    CA  Los Angeles  1562100
# 1827              Lake Hughes     NaN    CA  Los Angeles   285100
# 1828            East Pasadena     NaN    CA  Los Angeles  1006900
# 1829             Green Valley     NaN    CA  Los Angeles   274200
#
#       Unnamed: 0_x  Price level_x  Rating_x  Latitude_x  Longitude_x  \
# 0             76.0            NaN       4.7   34.143272  -118.031940
# 1             60.0            NaN       4.3   33.866461  -118.092799
# 2              8.0            1.0       4.2   34.004240  -118.409539
# 3              8.0            1.0       4.2   34.004240  -118.409539
# 4              8.0            1.0       4.2   34.004240  -118.409539
# 5              8.0            1.0       4.2   34.004240  -118.409539
# 6              8.0            1.0       4.2   34.004240  -118.409539
# 7              8.0            1.0       4.2   34.004240  -118.409539
# 8              8.0            1.0       4.2   34.004240  -118.409539
# 9              8.0            1.0       4.2   34.004240  -118.409539
# 10             8.0            1.0       4.2   34.004240  -118.409539
# 11             9.0            2.0       4.5   34.006537  -118.412160
# 12             9.0            2.0       4.5   34.006537  -118.412160
# 13             9.0            2.0       4.5   34.006537  -118.412160
# 14             9.0            2.0       4.5   34.006537  -118.412160
# 15             9.0            2.0       4.5   34.006537  -118.412160
# 16             9.0            2.0       4.5   34.006537  -118.412160
# 17             9.0            2.0       4.5   34.006537  -118.412160
# 18             9.0            2.0       4.5   34.006537  -118.412160
# 19             9.0            2.0       4.5   34.006537  -118.412160
# 20            26.0            1.0       4.2   34.004240  -118.409539
# 21            26.0            1.0       4.2   34.004240  -118.409539
# 22            26.0            1.0       4.2   34.004240  -118.409539
# 23            26.0            1.0       4.2   34.004240  -118.409539
# 24            26.0            1.0       4.2   34.004240  -118.409539
# 25            26.0            1.0       4.2   34.004240  -118.409539
# 26            26.0            1.0       4.2   34.004240  -118.409539
# 27            26.0            1.0       4.2   34.004240  -118.409539
# 28            26.0            1.0       4.2   34.004240  -118.409539
# 29            27.0            2.0       4.5   34.006537  -118.412160
# ...            ...            ...       ...         ...          ...
# 1800           NaN            NaN       NaN         NaN          NaN
# 1801           NaN            NaN       NaN         NaN          NaN
# 1802           NaN            NaN       NaN         NaN          NaN
# 1803           NaN            NaN       NaN         NaN          NaN
# 1804           NaN            NaN       NaN         NaN          NaN
# 1805           NaN            NaN       NaN         NaN          NaN
# 1806           NaN            NaN       NaN         NaN          NaN
# 1807           NaN            NaN       NaN         NaN          NaN
# 1808           NaN            NaN       NaN         NaN          NaN
# 1809           NaN            NaN       NaN         NaN          NaN
# 1810           NaN            NaN       NaN         NaN          NaN
# 1811           NaN            NaN       NaN         NaN          NaN
# 1812           NaN            NaN       NaN         NaN          NaN
# 1813           NaN            NaN       NaN         NaN          NaN
# 1814           NaN            NaN       NaN         NaN          NaN
# 1815           NaN            NaN       NaN         NaN          NaN
# 1816           NaN            NaN       NaN         NaN          NaN
# 1817           NaN            NaN       NaN         NaN          NaN
# 1818           NaN            NaN       NaN         NaN          NaN
# 1819           NaN            NaN       NaN         NaN          NaN
# 1820           NaN            NaN       NaN         NaN          NaN
# 1821           NaN            NaN       NaN         NaN          NaN
# 1822           NaN            NaN       NaN         NaN          NaN
# 1823           NaN            NaN       NaN         NaN          NaN
# 1824           NaN            NaN       NaN         NaN          NaN
# 1825           NaN            NaN       NaN         NaN          NaN
# 1826           NaN            NaN       NaN         NaN          NaN
# 1827           NaN            NaN       NaN         NaN          NaN
# 1828           NaN            NaN       NaN         NaN          NaN
# 1829           NaN            NaN       NaN         NaN          NaN
#
#      House Price Ranking  Unnamed: 0_y  Price level_y  Rating_y  Latitude_y  \
# 0                   High          76.0            NaN       4.7   34.143272
# 1                    Mid          60.0            NaN       4.3   33.866461
# 2                   High           8.0            1.0       4.2   34.004240
# 3                   High           9.0            2.0       4.5   34.006537
# 4                   High          27.0            1.0       4.2   34.004240
# 5                   High          28.0            2.0       4.5   34.006537
# 6                   High          46.0            1.0       4.2   34.004240
# 7                   High          47.0            2.0       4.5   34.006537
# 8                   High          79.0            1.0       4.2   34.004240
# 9                   High          86.0            1.0       4.2   34.004240
# 10                  High          87.0            2.0       4.5   34.006537
# 11                  High           8.0            1.0       4.2   34.004240
# 12                  High           9.0            2.0       4.5   34.006537
# 13                  High          27.0            1.0       4.2   34.004240
# 14                  High          28.0            2.0       4.5   34.006537
# 15                  High          46.0            1.0       4.2   34.004240
# 16                  High          47.0            2.0       4.5   34.006537
# 17                  High          79.0            1.0       4.2   34.004240
# 18                  High          86.0            1.0       4.2   34.004240
# 19                  High          87.0            2.0       4.5   34.006537
# 20                  High           8.0            1.0       4.2   34.004240
# 21                  High           9.0            2.0       4.5   34.006537
# 22                  High          27.0            1.0       4.2   34.004240
# 23                  High          28.0            2.0       4.5   34.006537
# 24                  High          46.0            1.0       4.2   34.004240
# 25                  High          47.0            2.0       4.5   34.006537
# 26                  High          79.0            1.0       4.2   34.004240
# 27                  High          86.0            1.0       4.2   34.004240
# 28                  High          87.0            2.0       4.5   34.006537
# 29                  High           8.0            1.0       4.2   34.004240
# ...                  ...           ...            ...       ...         ...
# 1800                 Low           NaN            NaN       NaN         NaN
# 1801                High           NaN            NaN       NaN         NaN
# 1802                 Low           NaN            NaN       NaN         NaN
# 1803                 Low           NaN            NaN       NaN         NaN
# 1804                 Low           NaN            NaN       NaN         NaN
# 1805                 Mid           NaN            NaN       NaN         NaN
# 1806                High           NaN            NaN       NaN         NaN
# 1807                High           NaN            NaN       NaN         NaN
# 1808                High           NaN            NaN       NaN         NaN
# 1809                High           NaN            NaN       NaN         NaN
# 1810                 Low           NaN            NaN       NaN         NaN
# 1811                 Mid           NaN            NaN       NaN         NaN
# 1812                 Mid           NaN            NaN       NaN         NaN
# 1813                 Low           NaN            NaN       NaN         NaN
# 1814                High           NaN            NaN       NaN         NaN
# 1815                 Mid           NaN            NaN       NaN         NaN
# 1816                High           NaN            NaN       NaN         NaN
# 1817                High           NaN            NaN       NaN         NaN
# 1818                 Mid           NaN            NaN       NaN         NaN
# 1819                High           NaN            NaN       NaN         NaN
# 1820                 Mid           NaN            NaN       NaN         NaN
# 1821                High           NaN            NaN       NaN         NaN
# 1822                 Low           NaN            NaN       NaN         NaN
# 1823                High           NaN            NaN       NaN         NaN
# 1824                High           NaN            NaN       NaN         NaN
# 1825                High           NaN            NaN       NaN         NaN
# 1826                High           NaN            NaN       NaN         NaN
# 1827                 Low           NaN            NaN       NaN         NaN
# 1828                High           NaN            NaN       NaN         NaN
# 1829                 Low           NaN            NaN       NaN         NaN
#
#       Longitude_y
# 0     -118.031940
# 1     -118.092799
# 2     -118.409539
# 3     -118.412160
# 4     -118.409539
# 5     -118.412160
# 6     -118.409539
# 7     -118.412160
# 8     -118.409539
# 9     -118.409539
# 10    -118.412160
# 11    -118.409539
# 12    -118.412160
# 13    -118.409539
# 14    -118.412160
# 15    -118.409539
# 16    -118.412160
# 17    -118.409539
# 18    -118.409539
# 19    -118.412160
# 20    -118.409539
# 21    -118.412160
# 22    -118.409539
# 23    -118.412160
# 24    -118.409539
# 25    -118.412160
# 26    -118.409539
# 27    -118.409539
# 28    -118.412160
# 29    -118.409539
# ...           ...
# 1800          NaN
# 1801          NaN
# 1802          NaN
# 1803          NaN
# 1804          NaN
# 1805          NaN
# 1806          NaN
# 1807          NaN
# 1808          NaN
# 1809          NaN
# 1810          NaN
# 1811          NaN
# 1812          NaN
# 1813          NaN
# 1814          NaN
# 1815          NaN
# 1816          NaN
# 1817          NaN
# 1818          NaN
# 1819          NaN
# 1820          NaN
# 1821          NaN
# 1822          NaN
# 1823          NaN
# 1824          NaN
# 1825          NaN
# 1826          NaN
# 1827          NaN
# 1828          NaN
# 1829          NaN
#
# [1830 rows x 16 columns]

# %%
merge1_pct=

# %%
merge1_pct=merge1.loc[merge1['RegionName'].isin(['Pasadena','Cerritos','Torrance'])]
merge1_pct
# Out:
#      RegionName  counts State   CountyName  2018-05  Unnamed: 0_x  \
# 1      Cerritos     1.0    CA  Los Angeles   742700          60.0
# 1496   Pasadena     1.0    CA  Los Angeles   921500          77.0
# 1655   Torrance     8.0    CA  Los Angeles   866700           0.0
# 1656   Torrance     8.0    CA  Los Angeles   866700           0.0
# 1657   Torrance     8.0    CA  Los Angeles   866700           0.0
# 1658   Torrance     8.0    CA  Los Angeles   866700           0.0
# 1659   Torrance     8.0    CA  Los Angeles   866700           0.0
# 1660   Torrance     8.0    CA  Los Angeles   866700           0.0
# 1661   Torrance     8.0    CA  Los Angeles   866700           0.0
# 1662   Torrance     8.0    CA  Los Angeles   866700           0.0
# 1663   Torrance     8.0    CA  Los Angeles   866700           1.0
# 1664   Torrance     8.0    CA  Los Angeles   866700           1.0
# 1665   Torrance     8.0    CA  Los Angeles   866700           1.0
# 1666   Torrance     8.0    CA  Los Angeles   866700           1.0
# 1667   Torrance     8.0    CA  Los Angeles   866700           1.0
# 1668   Torrance     8.0    CA  Los Angeles   866700           1.0
# 1669   Torrance     8.0    CA  Los Angeles   866700           1.0
# 1670   Torrance     8.0    CA  Los Angeles   866700           1.0
# 1671   Torrance     8.0    CA  Los Angeles   866700          20.0
# 
# 1692          41.0            2.0       4.6   33.836677  -118.318935
# 1693          80.0            NaN       5.0   33.815576  -118.351367
# 1694          81.0            2.0       4.6   33.836677  -118.318935
# 1695           0.0            2.0       4.6   33.836677  -118.318935
# 1696           1.0            NaN       5.0   33.815576  -118.351367
# 1697          20.0            2.0       4.6   33.836677  -118.318935
# 1698          21.0            NaN       5.0   33.815576  -118.351367
# 1699          40.0            NaN       5.0   33.815576  -118.351367
# 1700          41.0            2.0       4.6   33.836677  -118.318935
# 1701          80.0            NaN       5.0   33.815576  -118.351367
# 1702          81.0            2.0       4.6   33.836677  -118.318935
# 1703           0.0            2.0       4.6   33.836677  -118.318935
# 1704           1.0            NaN       5.0   33.815576  -118.351367
# 1705          20.0            2.0       4.6   33.836677  -118.318935
# 1706          21.0            NaN       5.0   33.815576  -118.351367
# 1707          40.0            NaN       5.0   33.815576  -118.351367
# 1708          41.0            2.0       4.6   33.836677  -118.318935
# 1709          80.0            NaN       5.0   33.815576  -118.351367
# 1710          81.0            2.0       4.6   33.836677  -118.318935
# 1711           0.0            2.0       4.6   33.836677  -118.318935
# 1712           1.0            NaN       5.0   33.815576  -118.351367
# 1713          20.0            2.0       4.6   33.836677  -118.318935
# 1714          21.0            NaN       5.0   33.815576  -118.351367
# 1715          40.0            NaN       5.0   33.815576  -118.351367
# 1716          41.0            2.0       4.6   33.836677  -118.318935
# 1717          80.0            NaN       5.0   33.815576  -118.351367
# 1718          81.0            2.0       4.6   33.836677  -118.318935
#
# [66 rows x 16 columns]

# %%
merge.to_csv("house_rest_ranking.csv")

# %%
#filter original dataframe to contain records for only cities in Los Angeles county
#home_prices_df = home_prices_df.loc[home_prices_df.CountyName == "Los Angeles"]
#home_prices_df.head()
#high value house >750000
#middle value house >55000
#lower<=550000

# %%
merge=merge.loc[merge.RegionName=="Azusa"]
merge
# Out:
#      RegionName State   CountyName  2018-05  Unnamed: 0_x  Price level_x  \
# 1662      Azusa    CA  Los Angeles   465800           NaN            NaN
#
#       Rating_x  Latitude_x  Longitude_x House Price Ranking  Unnamed: 0_y  \
# 1662       NaN         NaN          NaN                 Low           NaN
#
#       Price level_y  Rating_y  Latitude_y  Longitude_y
# 1662            NaN       NaN         NaN          NaN

# %% [markdown]
# # for index, row in res_area_list.iterrows():
#  ##   loc_lat = res_area_list['Location'][index]['location']['lat']
#  #   loc_lng = res_area_list['Location'][index]['location']['lng']
#  #   latitude_list.append(loc_lat)
#   #  longitude_list.append(loc_lng)
#
# # res_area_list['Latitude'] = latitude_list
# # res_area_list['Longitude'] = longitude_list

# %% [markdown]
# for index, row in merge.iterrows():
#     if  merge['2018-05'][index] >  750000:
#    # loc_lng = res_area_list['Location'][index]['location']['lng']
#         house_raking.append('High')
#     elif ( merge['2018-5'][index]>550000 and merge['2018-5'][index] < 750000 ):
#         house_raking.append('Mid')
#
#     elif merge['2018-05'][index] < 550000:
#         house_raking.append['Low']
#
# res_area_list['Longitude'] = house_raking

# %%
house_ranking=pd.read_csv('House_price_range.csv')

# %%
house_ranking
